# %% [markdown]
# <a href="https://colab.research.google.com/github/Lilaven/Prediction-Bankrupt-by-machine-learning/blob/master/Project_N1_Anhntn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kết nối với Google drive lưu dữ data

# %%
#import dataset
from google.colab import drive
drive.mount('/content/drive')
folder_path= "/content/drive/My Drive/AI Project N1"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Preparation
# Import các thư viện cần thiết

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from sklearn import preprocessing

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import os

def filepath(file_name):
  fname = 'Data/{}.csv'.format(file_name)
  fpath = os.path.join(folder_path, fname)
  return(fpath)

df = pd.read_csv(filepath('Datasetno0'), encoding='utf-8', sep=',')
df.head()
# Out:
#      ID_DN      CITY ENT_TYPE  ...   TongLN_2018 LNsauthue_2018  Status
# 0  ACT2535  0.624625       SC  ...  4.862783e+09   4.308773e+09     ACT
# 1  ACT0364  0.624625       SC  ...  5.597460e+07   4.392401e+07     ACT
# 2  ACT1689  0.624625       SC  ...  1.650249e+09   1.320199e+09     ACT
# 3  ACT2928  0.624625       SC  ...  5.539505e+10   4.469575e+10     ACT
# 4  ACT0607  0.624625       SC  ...  8.340658e+09   8.340658e+09     ACT
#
# [5 rows x 61 columns]

# %%
fdf = df[['TienTT_2015', 'ThuNH_2015', 'HangTon_2015', 'TSCoDinh_2015', 'NoNgan_2015', 'NoDai_2015', 'VonCSH_2015',
          'DTThuan_2015', 'GiaVon_2015', 'DThuTC_2015', 'LNThuan_2015', 'TongLN_2015', 'LNsauthue_2015',
          'TienTT_2016', 'ThuNH_2016', 'HangTon_2016', 'TSCoDinh_2016', 'NoNgan_2016', 'NoDai_2016', 'VonCSH_2016',
          'DTThuan_2016', 'GiaVon_2016', 'DThuTC_2016', 'LNThuan_2016', 'TongLN_2016', 'LNsauthue_2016',
          'TienTT_2017', 'ThuNH_2017', 'HangTon_2017', 'TSCoDinh_2017', 'NoNgan_2017', 'NoDai_2017', 'VonCSH_2017',
          'DTThuan_2017', 'GiaVon_2017', 'DThuTC_2017', 'LNThuan_2017', 'TongLN_2017', 'LNsauthue_2017',
          'TienTT_2018', 'ThuNH_2018', 'HangTon_2018', 'TSCoDinh_2018', 'NoNgan_2018', 'NoDai_2018', 'VonCSH_2018',
          'DTThuan_2018', 'GiaVon_2018', 'DThuTC_2018', 'LNThuan_2018', 'TongLN_2018', 'LNsauthue_2018',
          ]]
fdf.head()
# Out:
#     TienTT_2015    ThuNH_2015  ...   TongLN_2018  LNsauthue_2018
# 0  4.224591e+08  1.010693e+10  ...  4.862783e+09    4.308773e+09
# 1  1.709996e+09  2.205878e+10  ...  5.597460e+07    4.392401e+07
# 2  2.299011e+09  7.595245e+09  ...  1.650249e+09    1.320199e+09
# 3  2.800000e+12  6.110000e+12  ...  5.539505e+10    4.469575e+10
# 4  2.691355e+10  2.100000e+11  ...  8.340658e+09    8.340658e+09
#
# [5 rows x 52 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# Tìm các tất cả các giá trị có thể có của mỗi cột
u_gender = np.unique(df['LEGAL_GENDER'])
u_ent_type = np.unique(df['ENT_TYPE'])
u_ma_nganh = np.unique(df['MA_NGANH'])
u_status = np.unique(df['Status'])

# Matching mỗi giá trị (label) với số (index) thư viện đã mã hóa qua LabelEncoder()

le = LabelEncoder()
label_gender = le.fit_transform(df['LEGAL_GENDER'])
mapping_gender = {index: label for index, label in 
                  enumerate(le.classes_)}

label_ent_type = le.fit_transform(df['ENT_TYPE'])
mapping_ent_type = {index: label for index, label in 
                  enumerate(le.classes_)}


label_ma_nganh = le.fit_transform(df['MA_NGANH'])
mapping_ma_nganh= {index: label for index, label in 
                  enumerate(le.classes_)}

label_status = le.fit_transform(df['Status'])
mapping_status = {index: label for index, label in 
                  enumerate(le.classes_)}


mapping_gender, mapping_ent_type, mapping_ma_nganh, mapping_status
# Out:
# ({0: 'Female', 1: 'Male'},
#  {0: 'LLC1', 1: 'LLC2', 2: 'SC'},
#  {0: 1,
#   1: 2,
#   2: 3,
#   3: 5,
#   4: 7,
#   5: 8,
#   6: 10,
#   7: 11,
#   8: 13,
#   9: 14,
#   10: 15,
#   11: 16,
#   12: 17,
#   13: 18,
#   14: 19,
#   15: 20,
#   16: 21,
#   17: 22,
#   18: 23,
#   19: 24,
#   20: 25,
#   21: 26,
#   22: 27,
#   23: 28,
#   24: 29,
#   25: 30,
#   26: 31,
#   27: 32,
#   28: 33,
#   29: 35,
#   30: 36,
#   31: 37,
#   32: 38,
#   33: 39,
#   34: 41,
#   35: 42,
#   36: 43,
#   37: 45,
#   38: 46,
#   39: 47,
#   40: 49,
#   41: 50,
#   42: 52,
#   43: 53,
#   44: 55,
#   45: 56,
#   46: 58,
#   47: 59,
#   48: 61,
#   49: 62,
#   50: 63,
#   51: 64,
#   52: 65,
#   53: 66,
#   54: 68,
#   55: 69,
#   56: 70,
#   57: 71,
#   58: 72,
#   59: 73,
#   60: 74,
#   61: 77,
#   62: 78,
#   63: 79,
#   64: 80,
#   65: 81,
#   66: 82,
#   67: 85,
#   68: 86,
#   69: 90,
#   70: 92,
#   71: 93,
#   72: 95,
#   73: 96},
#  {0: 'ACT', 1: 'TER'})

# %%
#Tạo one hot encode cho các trường và chèn dữ liệu one hot encoding vào bảng
gender_onehot = pd.get_dummies(df['LEGAL_GENDER'], prefix='Gender')
ent_type_onehot = pd.get_dummies(df['ENT_TYPE'], prefix='Ent_type')
ma_nganh_onehot = pd.get_dummies(df['MA_NGANH'], prefix='Ma_nganh')
status_onehot = pd.get_dummies(df['Status'], prefix='Status')

en1_df = pd.concat([df[['ID_DN', 'CITY', 'ENT_TYPE']], ent_type_onehot,
                 df[['AGE', 'LEGAL_GENDER']], gender_onehot,
                 df[['CAPITAL_AMOUNT', 'TOTAL_OF_LABORS','MA_NGANH']], ma_nganh_onehot, fdf, df['Status'], status_onehot], axis=1)

#Xóa các cột không cần thiết
endf = en1_df.drop(columns=['ENT_TYPE', 'LEGAL_GENDER', 'MA_NGANH', 'Status'])

endf
# Out:
#         ID_DN      CITY  Ent_type_LLC1  ...  LNsauthue_2018  Status_ACT  Status_TER
# 0     ACT2535  0.624625              0  ...    4.308773e+09           1           0
# 1     ACT0364  0.624625              0  ...    4.392401e+07           1           0
# 2     ACT1689  0.624625              0  ...    1.320199e+09           1           0
# 3     ACT2928  0.624625              0  ...    4.469575e+10           1           0
# 4     ACT0607  0.624625              0  ...    8.340658e+09           1           0
# ...       ...       ...            ...  ...             ...         ...         ...
# 5253  ACT0155  0.539675              1  ...    9.677581e+07           1           0
# 5254  TER1007  0.539675              1  ...   -4.267700e+05           0           1
# 5255  ACT2469  0.539675              1  ...    1.858495e+07           1           0
# 5256  TER2039  0.539675              1  ...   -1.897276e+07           0           1
# 5257  ACT2543  0.539675              1  ...    4.011527e+08           1           0
#
# [5258 rows x 138 columns]

# %%
endf.describe()
# Out:
#               CITY  Ent_type_LLC1  ...   Status_ACT   Status_TER
# count  5258.000000    5258.000000  ...  5258.000000  5258.000000
# mean      0.625803       0.372955  ...     0.540129     0.459871
# std       0.020244       0.483636  ...     0.498434     0.498434
# min       0.539675       0.000000  ...     0.000000     0.000000
# 25%       0.620475       0.000000  ...     0.000000     0.000000
# 50%       0.629300       0.000000  ...     1.000000     0.000000
# 75%       0.634025       1.000000  ...     1.000000     1.000000
# max       0.690250       1.000000  ...     1.000000     1.000000
#
# [8 rows x 137 columns]

# %%
npdf = endf.to_numpy()
data = npdf[:,1:136]
datanf = npdf[:,1:84]
dataf = npdf[:,84:136]
label = npdf[:,136:138]

#Chia tập train, valid và test
from sklearn.model_selection import train_test_split
x, x_test, y, y_test = train_test_split(data,label, test_size=0.15, random_state=2)
x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size = 0.1, random_state=2)
x_train.shape, x_valid.shape, x_test.shape, y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((4022, 135), (447, 135), (789, 135), (4022, 2), (447, 2), (789, 2))

# %%
#Logarit tự nhiên các data tài chính trên 2 tập train và test
def logaritdata(ds):
  sign_ds = ds.copy()
  abs_ds = ds.copy().astype(float)
  ln_ds = ds.copy()
  ds_o = ds.copy()
  sign_ds[:,83:135] = np.sign(ds_o[:, 83:135])
  abs_ds[:,83:135] = np.absolute(ds_o[:,83:135])
  ln_ds[:,83:135] = np.multiply(np.log(abs_ds[:,83:135]), sign_ds[:,83:135])
  ds[:,83:135] = ln_ds[:,83:135] 
  return ds

logaritdata(x_train)
logaritdata(x_valid)
logaritdata(x_test)

x_train, x_valid, x_test
# Out:
# (array([[0.6142, 0, 1, ..., 17.016151941290016, 17.016151941290016,
#          16.793008389975807],
#         [0.634025, 0, 1, ..., -14.536717359302175, -14.536717359302175,
#          -14.536717359302175],
#         [0.624625, 1, 0, ..., 14.851951654492362, 14.60125241650672,
#          14.60125241650672],
#         ...,
#         [0.63255, 1, 0, ..., 18.512856069777918, 18.512856069777918,
#          18.512856069777918],
#         [0.634025, 0, 0, ..., -14.581510351615805, -14.581510351615805,
#          -14.581510351615805],
#         [0.634025, 1, 0, ..., -14.628660530918916, -14.628660530918916,
#          -14.628660530918916]], dtype=object),
#  array([[0.62755, 0, 1, ..., 14.916375307935676, 14.916203347555323,
#          14.916203347555323],
#         [0.624625, 0, 1, ..., 17.47459697440569, 17.47459697440569,
#          17.25145342953049],
#         [0.634025, 1, 0, ..., 24.25840918292387, 24.25840918292387,
#          24.25840918292387],
#         ...,
#         [0.5884, 1, 0, ..., -17.02500362208092, -17.02500362208092,
#          -17.02500362208092],
#         [0.634025, 1, 0, ..., 20.63966782198457, 19.788923078280472,
#          19.565779526329877],
#         [0.633725, 1, 0, ..., -21.67546577884085, -21.675986469739165,
#          -21.675986469739165]], dtype=object),
#  array([[0.624625, 1, 0, ..., -18.537517340765657, -18.538333282205443,
#          -18.538333282205443],
#         [0.634025, 0, 1, ..., -18.789009951374695, -18.789009951374695,
#          -18.789009951374695],
#         [0.567475, 0, 0, ..., 18.418963660608167, 18.418963660608167,
#          18.418963660608167],
#         ...,
#         [0.6758, 1, 0, ..., 0.0, 0.0, 0.0],
#         [0.634625, 1, 0, ..., -15.232795220513514, -15.232795220513514,
#          -15.232795220513514],
#         [0.634025, 0, 1, ..., -14.757226122095418, -14.757226122095418,
#          -14.757226122095418]], dtype=object))

# %%
#Rescale Data - Điều chỉnh tỉ lệ

def rescaledata(dataset):
  #Rescale AGE
  age = dataset[:,4].reshape(-1,1)
  sage = preprocessing.MinMaxScaler(feature_range= (0,1)).fit_transform(age)
  dataset[:,4].reshape(-1,1)
  dataset[:,4] = sage[:,0]
  #Rescale CAPITAL_AMOUNT
  capital= dataset[:,7].reshape(-1,1)
  scapital = preprocessing.MinMaxScaler(feature_range= (0,1)).fit_transform(capital)
  dataset[:,7].reshape(-1,1)
  dataset[:,7] = scapital[:,0]
  #Rescale TOTAL_OF_LABORS
  totallabor= dataset[:,8].reshape(-1,1)
  stotallabor = preprocessing.MinMaxScaler(feature_range= (0,1)).fit_transform(totallabor)
  dataset[:,8].reshape(-1,1)
  dataset[:,8] = stotallabor[:,0]
  #Rescale data tài chính
  # dataf = dataset[:,84:136]
  # sdataf = preprocessing.MinMaxScaler(feature_range= (-1,1)).fit_transform(dataf)
  # dataset[:,84:136] = sdataf[:,:]
  return dataset

rescaledata(x_train)
rescaledata(x_valid)
rescaledata(x_test)

#Chuyển numpy array object to float
x_train = np.array(x_train, dtype=float)
x_valid = np.array(x_valid, dtype=float)
x_test = np.array(x_test, dtype=float)
y_train = np.array(y_train, dtype=float)
y_valid = np.array(y_valid, dtype=float)
y_test = np.array(y_test, dtype=float)

x_train.dtype
# Out:
# dtype('float64')

# %%
# np.savetxt('dataen.csv', x_train, delimiter=',')
np.savetxt('dataenY.csv', y_train, delimiter=',')

# %%
#Convert numpy sang torch

def convert_to_tensor(x, y):
    x_torch = torch.from_numpy(x).float()
    y_torch = torch.from_numpy(y).float()
    return x_torch, y_torch

x_train_ts, y_train_ts = convert_to_tensor(x_train, y_train)
x_valid_ts, y_valid_ts = convert_to_tensor(x_valid, y_valid)
x_test_ts, y_test_ts = convert_to_tensor(x_test, y_test)

# %%
#Model mlp

class Mymodel1(nn.Module):
    def __init__(self, input, hidden1, hidden2, output):
        super(Mymodel1, self).__init__()
        self.model = nn.Sequential(
            nn.Dropout(p=0.1),
            nn.Linear(input, hidden1),
            nn.Tanh(),
            nn.Dropout(p=0.05),        
            nn.Linear(hidden1, hidden2),
            nn.Tanh(), 
            nn.Linear(hidden2, output),
            nn.Softmax(dim=1),
        )

    def forward(self, input):
        y_pred = self.model(input)
        return y_pred

# %%
from torch.optim import Adam

mean_train_losses = []
mean_valid_losses = []
valid_acc_list = []
N_epocs, batch_size = 50000, 128
input, hidden1, hidden2, output = 135, 64, 8, 2

model = Mymodel1(input, hidden1, hidden2, output)
modelv = Mymodel1(input, hidden1, hidden2, output)
criterion = nn.MSELoss()
optimizer = Adam(model.parameters(), lr=1e-6, eps=1e-8)

for epoch in range(N_epocs):
    model.train()
    train_losses = []
    valid_losses = []
        
    optimizer.zero_grad()
    y_pred = model(x_train_ts)
    loss = criterion(y_pred, y_train_ts)
    loss.backward()
    optimizer.step()    
    train_losses.append(loss.item())
        
    if epoch%500 == 499:
      model.eval()
      correct = 0
      total = 0
      with torch.no_grad():
        y_pred_v = model(x_valid_ts)
        loss = criterion(y_pred_v, y_valid_ts.long())
        valid_losses.append(loss.item())
        _, predicted = torch.max(y_pred_v, 1)
        _, gt = torch.max(y_valid_ts, 1)
        correct += (predicted == gt).sum().item()
        total += y_valid_ts.size(0)
        
      mean_train_losses.append(np.mean(train_losses))
      mean_valid_losses.append(np.mean(valid_losses))
      
      accuracy = 100*correct/total
      valid_acc_list.append(accuracy)
      print('epoch : {}, train loss : {:.4f}, valid loss : {:.4f}, valid acc : {:.3f}%'\
          .format(epoch+1, np.mean(train_losses), np.mean(valid_losses), accuracy))
# Out:
# epoch : 500, train loss : 0.2355, valid loss : 0.2270, valid acc : 61.298%
# epoch : 1000, train loss : 0.2315, valid loss : 0.2226, valid acc : 64.206%
# epoch : 1500, train loss : 0.2291, valid loss : 0.2188, valid acc : 66.219%
# epoch : 2000, train loss : 0.2247, valid loss : 0.2154, valid acc : 67.785%
# epoch : 2500, train loss : 0.2228, valid loss : 0.2124, valid acc : 67.785%
# epoch : 3000, train loss : 0.2202, valid loss : 0.2097, valid acc : 68.009%
# epoch : 3500, train loss : 0.2190, valid loss : 0.2073, valid acc : 68.233%
# epoch : 4000, train loss : 0.2182, valid loss : 0.2051, valid acc : 67.785%
# epoch : 4500, train loss : 0.2146, valid loss : 0.2030, valid acc : 68.904%
# epoch : 5000, train loss : 0.2125, valid loss : 0.2010, valid acc : 70.022%
# epoch : 5500, train loss : 0.2119, valid loss : 0.1991, valid acc : 70.694%
# epoch : 6000, train loss : 0.2096, valid loss : 0.1973, valid acc : 70.470%
# epoch : 6500, train loss : 0.2079, valid loss : 0.1955, valid acc : 71.365%
# epoch : 7000, train loss : 0.2068, valid loss : 0.1939, valid acc : 72.260%
# epoch : 7500, train loss : 0.2057, valid loss : 0.1923, valid acc : 72.483%
# epoch : 8000, train loss : 0.2041, valid loss : 0.1909, valid acc : 72.931%
# epoch : 8500, train loss : 0.2029, valid loss : 0.1895, valid acc : 74.273%
# epoch : 9000, train loss : 0.2027, valid loss : 0.1881, valid acc : 75.168%
# epoch : 9500, train loss : 0.2005, valid loss : 0.1868, valid acc : 75.615%
# epoch : 10000, train loss : 0.1998, valid loss : 0.1855, valid acc : 75.839%
# epoch : 10500, train loss : 0.1969, valid loss : 0.1843, valid acc : 76.063%
# epoch : 11000, train loss : 0.1967, valid loss : 0.1832, valid acc : 76.510%
# epoch : 11500, train loss : 0.1954, valid loss : 0.1821, valid acc : 76.734%
# epoch : 12000, train loss : 0.1939, valid loss : 0.1810, valid acc : 76.510%
# epoch : 12500, train loss : 0.1932, valid loss : 0.1799, valid acc : 76.734%
# epoch : 13000, train loss : 0.1923, valid loss : 0.1789, valid acc : 76.734%
# epoch : 13500, train loss : 0.1912, valid loss : 0.1778, valid acc : 76.286%
# epoch : 14000, train loss : 0.1904, valid loss : 0.1769, valid acc : 76.286%
# epoch : 14500, train loss : 0.1907, valid loss : 0.1759, valid acc : 76.734%
# epoch : 15000, train loss : 0.1871, valid loss : 0.1750, valid acc : 77.181%
# epoch : 15500, train loss : 0.1891, valid loss : 0.1740, valid acc : 77.405%
# epoch : 16000, train loss : 0.1877, valid loss : 0.1731, valid acc : 77.405%
# epoch : 16500, train loss : 0.1852, valid loss : 0.1722, valid acc : 77.405%
# epoch : 17000, train loss : 0.1854, valid loss : 0.1713, valid acc : 77.405%
# epoch : 17500, train loss : 0.1850, valid loss : 0.1704, valid acc : 77.405%
# epoch : 18000, train loss : 0.1830, valid loss : 0.1695, valid acc : 78.076%
# epoch : 18500, train loss : 0.1826, valid loss : 0.1686, valid acc : 77.852%
# epoch : 19000, train loss : 0.1815, valid loss : 0.1678, valid acc : 77.405%
# epoch : 19500, train loss : 0.1806, valid loss : 0.1670, valid acc : 77.629%
# epoch : 20000, train loss : 0.1789, valid loss : 0.1662, valid acc : 77.629%
# epoch : 20500, train loss : 0.1787, valid loss : 0.1655, valid acc : 77.629%
# epoch : 21000, train loss : 0.1792, valid loss : 0.1647, valid acc : 77.405%
# epoch : 21500, train loss : 0.1775, valid loss : 0.1640, valid acc : 77.629%
# epoch : 22000, train loss : 0.1762, valid loss : 0.1633, valid acc : 78.300%
# epoch : 22500, train loss : 0.1755, valid loss : 0.1626, valid acc : 78.300%
# epoch : 23000, train loss : 0.1760, valid loss : 0.1619, valid acc : 78.523%
# epoch : 23500, train loss : 0.1757, valid loss : 0.1613, valid acc : 78.747%
# epoch : 24000, train loss : 0.1736, valid loss : 0.1606, valid acc : 79.195%
# epoch : 24500, train loss : 0.1743, valid loss : 0.1600, valid acc : 79.195%
# epoch : 25000, train loss : 0.1705, valid loss : 0.1594, valid acc : 79.642%
# epoch : 25500, train loss : 0.1727, valid loss : 0.1588, valid acc : 79.866%
# epoch : 26000, train loss : 0.1704, valid loss : 0.1581, valid acc : 80.089%
# epoch : 26500, train loss : 0.1712, valid loss : 0.1576, valid acc : 80.089%
# epoch : 27000, train loss : 0.1698, valid loss : 0.1570, valid acc : 79.866%
# epoch : 27500, train loss : 0.1681, valid loss : 0.1564, valid acc : 79.866%
# epoch : 28000, train loss : 0.1682, valid loss : 0.1559, valid acc : 79.866%
# epoch : 28500, train loss : 0.1697, valid loss : 0.1554, valid acc : 79.866%
# epoch : 29000, train loss : 0.1655, valid loss : 0.1548, valid acc : 80.089%
# epoch : 29500, train loss : 0.1677, valid loss : 0.1543, valid acc : 80.089%
# epoch : 30000, train loss : 0.1688, valid loss : 0.1538, valid acc : 79.866%
# epoch : 30500, train loss : 0.1656, valid loss : 0.1533, valid acc : 79.866%
# epoch : 31000, train loss : 0.1648, valid loss : 0.1529, valid acc : 79.866%
# epoch : 31500, train loss : 0.1663, valid loss : 0.1524, valid acc : 79.642%
# epoch : 32000, train loss : 0.1665, valid loss : 0.1519, valid acc : 79.642%
# epoch : 32500, train loss : 0.1631, valid loss : 0.1515, valid acc : 80.089%
# epoch : 33000, train loss : 0.1643, valid loss : 0.1511, valid acc : 80.089%
# epoch : 33500, train loss : 0.1627, valid loss : 0.1507, valid acc : 80.089%
# epoch : 34000, train loss : 0.1634, valid loss : 0.1503, valid acc : 80.089%
# epoch : 34500, train loss : 0.1647, valid loss : 0.1499, valid acc : 80.089%
# epoch : 35000, train loss : 0.1613, valid loss : 0.1495, valid acc : 80.089%
# epoch : 35500, train loss : 0.1604, valid loss : 0.1491, valid acc : 80.313%
# epoch : 36000, train loss : 0.1610, valid loss : 0.1488, valid acc : 80.313%
# epoch : 36500, train loss : 0.1624, valid loss : 0.1484, valid acc : 80.313%
# epoch : 37000, train loss : 0.1622, valid loss : 0.1481, valid acc : 80.313%
# epoch : 37500, train loss : 0.1603, valid loss : 0.1477, valid acc : 80.313%
# epoch : 38000, train loss : 0.1608, valid loss : 0.1474, valid acc : 80.537%
# epoch : 38500, train loss : 0.1597, valid loss : 0.1471, valid acc : 80.537%
# epoch : 39000, train loss : 0.1620, valid loss : 0.1468, valid acc : 80.313%
# epoch : 39500, train loss : 0.1583, valid loss : 0.1465, valid acc : 80.537%
# epoch : 40000, train loss : 0.1572, valid loss : 0.1462, valid acc : 80.537%
# epoch : 40500, train loss : 0.1574, valid loss : 0.1459, valid acc : 80.537%
# epoch : 41000, train loss : 0.1562, valid loss : 0.1456, valid acc : 80.537%
# epoch : 41500, train loss : 0.1567, valid loss : 0.1454, valid acc : 80.537%
# epoch : 42000, train loss : 0.1567, valid loss : 0.1451, valid acc : 80.537%
# epoch : 42500, train loss : 0.1590, valid loss : 0.1448, valid acc : 80.761%
# epoch : 43000, train loss : 0.1584, valid loss : 0.1445, valid acc : 80.761%
# epoch : 43500, train loss : 0.1579, valid loss : 0.1443, valid acc : 80.761%
# epoch : 44000, train loss : 0.1570, valid loss : 0.1441, valid acc : 80.761%
# epoch : 44500, train loss : 0.1582, valid loss : 0.1439, valid acc : 80.761%
# epoch : 45000, train loss : 0.1578, valid loss : 0.1437, valid acc : 80.761%
# epoch : 45500, train loss : 0.1560, valid loss : 0.1434, valid acc : 80.537%
# epoch : 46000, train loss : 0.1564, valid loss : 0.1432, valid acc : 80.537%
# epoch : 46500, train loss : 0.1536, valid loss : 0.1430, valid acc : 80.537%
# epoch : 47000, train loss : 0.1538, valid loss : 0.1428, valid acc : 80.984%
# epoch : 47500, train loss : 0.1568, valid loss : 0.1426, valid acc : 80.984%
# epoch : 48000, train loss : 0.1547, valid loss : 0.1424, valid acc : 80.984%
# epoch : 48500, train loss : 0.1538, valid loss : 0.1423, valid acc : 80.984%
# epoch : 49000, train loss : 0.1590, valid loss : 0.1421, valid acc : 81.208%
# epoch : 49500, train loss : 0.1546, valid loss : 0.1419, valid acc : 81.208%
# epoch : 50000, train loss : 0.1549, valid loss : 0.1417, valid acc : 81.208%

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))
ax1.plot(mean_train_losses, label='train')
ax1.plot(mean_valid_losses, label='valid')
lines, labels = ax1.get_legend_handles_labels()
ax1.legend(lines, labels, loc='best')

ax2.plot(valid_acc_list, label='valid acc')
ax2.legend()

# %%
def test_acc(model):
  correct = 0
  total = 0
  with torch.no_grad():
    for i in range(len(x_test_ts[:,1])):
      y_pred_t = model(x_test_ts)
      _, predicted = torch.max(y_pred_t, 1)
      _, gt = torch.max(y_test_ts, 1)
      correct += (predicted == gt).sum().item()
      total += y_test_ts.size(0)
  accuracy = 100*correct/total
  print('Accuracy of testdata: {:.3f}%'.format(accuracy))

test_acc(model)
# Out:
# Accuracy of testdata: 80.101%
